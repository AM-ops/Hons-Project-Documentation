# %% [markdown]
# Install all the relevant Libraries needed

# %%
# !pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 1.0 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 6.3 MB 38.8 MB/s
# ...
#      |████████████████████████████████| 15.4 MB 37 kB/s
# ...

# %% [markdown]
# Import all the Libraries needed

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point, Polygon

# %% [markdown]
# Mount the data files from my Google Drive account

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Assign the root folder for where the Data files are located

# %%
root_path = '/content/drive/MyDrive/HonsProj-Data'

# %%
melusi_map = gpd.read_file('/content/drive/MyDrive/HonsProj-Data/GTI_Data_Delivery20210902/SHP/Melusi_Area.shp')
melusi_map.plot()

# %%
melusi_map_2010 = gpd.read_file('/content/drive/MyDrive/HonsProj-Data/GTI_Data_Delivery20210902/SHP/Melusi_Building_Based_Land_Use_Points_2010.shp')
melusi_map_2010.plot()

# %%
melusi_map_2020 = gpd.read_file('/content/drive/MyDrive/HonsProj-Data/GTI_Data_Delivery20210902/SHP/Melusi_Building_Based_Land_Use_Points_2020.shp')
melusi_map_2020.plot()

# %%
sa_roads = gpd.read_file('/content/drive/MyDrive/HonsProj-Data/roads_lines_shp/hotosm_zaf_roads_lines.shp')
sa_roads.plot()

# %%
sa_rivers = gpd.read_file('/content/drive/MyDrive/HonsProj-Data/All-rivers/wriall500.shp')
sa_rivers.plot()
